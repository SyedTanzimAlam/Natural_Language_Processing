# %%
import tensorflow as tf
import numpy as np
import unicodedata
import re

raw_data = (
    ('What a ridiculous concept!', 'Quel concept ridicule !'),
    ('Your idea is not entirely crazy.', "Votre idée n'est pas complètement folle."),
    ("A man's worth lies in what he is.", "La valeur d'un homme réside dans ce qu'il est."),
    ('What he did is very wrong.', "Ce qu'il a fait est très mal."),
    ("All three of you need to do that.", "Vous avez besoin de faire cela, tous les trois."),
    ("Are you giving me another chance?", "Me donnez-vous une autre chance ?"),
    ("Both Tom and Mary work as models.", "Tom et Mary travaillent tous les deux comme mannequins."),
    ("Can I have a few minutes, please?", "Puis-je avoir quelques minutes, je vous prie ?"),
    ("Could you close the door, please?", "Pourriez-vous fermer la porte, s'il vous plaît ?"),
    ("Did you plant pumpkins this year?", "Cette année, avez-vous planté des citrouilles ?"),
    ("Do you ever study in the library?", "Est-ce que vous étudiez à la bibliothèque des fois ?"),
    ("Don't be deceived by appearances.", "Ne vous laissez pas abuser par les apparences."),
    ("Excuse me. Can you speak English?", "Je vous prie de m'excuser ! Savez-vous parler anglais ?"),
    ("Few people know the true meaning.", "Peu de gens savent ce que cela veut réellement dire."),
    ("Germany produced many scientists.", "L'Allemagne a produit beaucoup de scientifiques."),
    ("Guess whose birthday it is today.", "Devine de qui c'est l'anniversaire, aujourd'hui !"),
    ("He acted like he owned the place.", "Il s'est comporté comme s'il possédait l'endroit."),
    ("Honesty will pay in the long run.", "L'honnêteté paye à la longue."),
    ("How do we know this isn't a trap?", "Comment savez-vous qu'il ne s'agit pas d'un piège ?"),
    ("I can't believe you're giving up.", "Je n'arrive pas à croire que vous abandonniez."),
)

# %%
print(raw_data[0])
# Out:
# ('What a ridiculous concept!', 'Quel concept ridicule !')

# %%
def unicode_to_ascii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn')


def normalize_string(s):
    s = unicode_to_ascii(s)
    s = re.sub(r'([!.?])', r' \1', s)
    s = re.sub(r'[^a-zA-Z.!?]+', r' ', s)
    s = re.sub(r'\s+', r' ', s)
    return s

# %%
raw_data
# Out:
# (('What a ridiculous concept!', 'Quel concept ridicule !'),
#  ('Your idea is not entirely crazy.',
#   "Votre idée n'est pas complètement folle."),
#  ("A man's worth lies in what he is.",
#   "La valeur d'un homme réside dans ce qu'il est."),
#  ('What he did is very wrong.', "Ce qu'il a fait est très mal."),
#  ('All three of you need to do that.',
#   'Vous avez besoin de faire cela, tous les trois.'),
#  ('Are you giving me another chance?', 'Me donnez-vous une autre chance ?'),
#  ('Both Tom and Mary work as models.',
#   'Tom et Mary travaillent tous les deux comme mannequins.'),
#  ('Can I have a few minutes, please?',
#   'Puis-je avoir quelques minutes, je vous prie ?'),
#  ('Could you close the door, please?',
#   "Pourriez-vous fermer la porte, s'il vous plaît ?"),
#  ('Did you plant pumpkins this year?',
#   'Cette année, avez-vous planté des citrouilles\u202f?'),
#  ('Do you ever study in the library?',
#   'Est-ce que vous étudiez à la bibliothèque des fois ?'),
#  ("Don't be deceived by appearances.",
#   'Ne vous laissez pas abuser par les apparences.'),
#  ('Excuse me. Can you speak English?',
#   "Je vous prie de m'excuser ! Savez-vous parler anglais ?"),
#  ('Few people know the true meaning.',
#   'Peu de gens savent ce que cela veut réellement dire.'),
#  ('Germany produced many scientists.',
#   "L'Allemagne a produit beaucoup de scientifiques."),
#  ('Guess whose birthday it is today.',
#   "Devine de qui c'est l'anniversaire, aujourd'hui !"),
#  ('He acted like he owned the place.',
#   "Il s'est comporté comme s'il possédait l'endroit."),
#  ('Honesty will pay in the long run.', "L'honnêteté paye à la longue."),
#  ("How do we know this isn't a trap?",
#   "Comment savez-vous qu'il ne s'agit pas d'un piège ?"),
#  ("I can't believe you're giving up.",
#   "Je n'arrive pas à croire que vous abandonniez."))

# %%
raw_data_en, raw_data_fr = list(zip(*raw_data))
raw_data_en, raw_data_fr = list(raw_data_en), list(raw_data_fr)

raw_data_en = [normalize_string(data) for data in raw_data_en]
raw_data_fr_in = ['<start> ' + normalize_string(data) for data in raw_data_fr]
raw_data_fr_out = [normalize_string(data) + ' <end>' for data in raw_data_fr]

# %%
en_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')

# %%
en_tokenizer.fit_on_texts(raw_data_en)

# %%
print(en_tokenizer.word_index)
# Out:
# {'.': 1, 'you': 2, '?': 3, 'the': 4, 'a': 5, 'is': 6, 'he': 7, 'what': 8, 'in': 9, 'do': 10, 'can': 11, 't': 12, 'did': 13, 'giving': 14, 'me': 15, 'i': 16, 'few': 17, 'please': 18, 'this': 19, 'know': 20, 'ridiculous': 21, 'concept': 22, '!': 23, 'your': 24, 'idea': 25, 'not': 26, 'entirely': 27, 'crazy': 28, 'man': 29, 's': 30, 'worth': 31, 'lies': 32, 'very': 33, 'wrong': 34, 'all': 35, 'three': 36, 'of': 37, 'need': 38, 'to': 39, 'that': 40, 'are': 41, 'another': 42, 'chance': 43, 'both': 44, 'tom': 45, 'and': 46, 'mary': 47, 'work': 48, 'as': 49, 'models': 50, 'have': 51, 'minutes': 52, 'could': 53, 'close': 54, 'door': 55, 'plant': 56, 'pumpkins': 57, 'year': 58, 'ever': 59, 'study': 60, 'library': 61, 'don': 62, 'be': 63, 'deceived': 64, 'by': 65, 'appearances': 66, 'excuse': 67, 'speak': 68, 'english': 69, 'people': 70, 'true': 71, 'meaning': 72, 'germany': 73, 'produced': 74, 'many': 75, 'scientists': 76, 'guess': 77, 'whose': 78, 'birthday': 79, 'it': 80, 'today': 81, 'acted': 82, 'like': 83, 'owned': 84, 'place': 85, 'honesty': 86, 'will': 87, 'pay': 88, 'long': 89, 'run': 90, 'how': 91, 'we': 92, 'isn': 93, 'trap': 94, 'believe': 95, 're': 96, 'up': 97}

# %%
data_en = en_tokenizer.texts_to_sequences(raw_data_en)

# %%
data_en = tf.keras.preprocessing.sequence.pad_sequences(data_en,
                                                        padding='post')

# %%
print(data_en[:3])
# Out:
# [[ 8  5 21 22 23  0  0  0  0  0]
#  [24 25  6 26 27 28  1  0  0  0]
#  [ 5 29 30 31 32  9  8  7  6  1]]

# %%
fr_tokenizer = tf.keras.preprocessing.text.Tokenizer(filters='')

# ATTENTION: always finish with fit_on_texts before moving on
fr_tokenizer.fit_on_texts(raw_data_fr_in)
fr_tokenizer.fit_on_texts(raw_data_fr_out)

data_fr_in = fr_tokenizer.texts_to_sequences(raw_data_fr_in)
data_fr_in = tf.keras.preprocessing.sequence.pad_sequences(data_fr_in,
                                                           padding='post')

data_fr_out = fr_tokenizer.texts_to_sequences(raw_data_fr_out)
data_fr_out = tf.keras.preprocessing.sequence.pad_sequences(data_fr_out,
                                                            padding='post')

# %%
dataset = tf.data.Dataset.from_tensor_slices(
    (data_en, data_fr_in, data_fr_out))
dataset = dataset.shuffle(20).batch(5)

# %%
class Encoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Encoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)

    def call(self, sequence, states):
        embed = self.embedding(sequence)
        output, state_h, state_c = self.lstm(embed, initial_state=states)

        return output, state_h, state_c

    def init_states(self, batch_size):
        return (tf.zeros([batch_size, self.lstm_size]),
                tf.zeros([batch_size, self.lstm_size]))

# %%
class Decoder(tf.keras.Model):
    def __init__(self, vocab_size, embedding_size, lstm_size):
        super(Decoder, self).__init__()
        self.lstm_size = lstm_size
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_size)
        self.lstm = tf.keras.layers.LSTM(
            lstm_size, return_sequences=True, return_state=True)
        self.dense = tf.keras.layers.Dense(vocab_size)

    def call(self, sequence, state):
        embed = self.embedding(sequence)
        lstm_out, state_h, state_c = self.lstm(embed, state)
        logits = self.dense(lstm_out)

        return logits, state_h, state_c

# %%
EMBEDDING_SIZE = 32
LSTM_SIZE = 64

en_vocab_size = len(en_tokenizer.word_index) + 1
encoder = Encoder(en_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)

fr_vocab_size = len(fr_tokenizer.word_index) + 1
decoder = Decoder(fr_vocab_size, EMBEDDING_SIZE, LSTM_SIZE)

source_input = tf.constant([[1, 3, 5, 7, 2, 0, 0, 0]])
initial_state = encoder.init_states(1)
encoder_output, en_state_h, en_state_c = encoder(source_input, initial_state)

target_input = tf.constant([[1, 4, 6, 9, 2, 0, 0]])
decoder_output, de_state_h, de_state_c = decoder(target_input, (en_state_h, en_state_c))

print('Source sequences', source_input.shape)
print('Encoder outputs', encoder_output.shape)
print('Encoder state_h', en_state_h.shape)
print('Encoder state_c', en_state_c.shape)

print('\nDestination vocab size', fr_vocab_size)
print('Destination sequences', target_input.shape)
print('Decoder outputs', decoder_output.shape)
print('Decoder state_h', de_state_h.shape)
print('Decoder state_c', de_state_c.shape)
# Out:
# Source sequences (1, 8)
# Encoder outputs (1, 8, 64)
# Encoder state_h (1, 64)
# Encoder state_c (1, 64)
#
# Destination vocab size 110
# Destination sequences (1, 7)
# Decoder outputs (1, 7, 110)
# Decoder state_h (1, 64)
# Decoder state_c (1, 64)

# %%
def loss_func(targets, logits):
    crossentropy = tf.keras.losses.SparseCategoricalCrossentropy(
        from_logits=True)
    mask = tf.math.logical_not(tf.math.equal(targets, 0))
    mask = tf.cast(mask, dtype=tf.int64)
    loss = crossentropy(targets, logits, sample_weight=mask)

    return loss

# %%
optimizer = tf.keras.optimizers.Adam()

# %%
@tf.function
def train_step(source_seq, target_seq_in, target_seq_out, en_initial_states):
    with tf.GradientTape() as tape:
        en_outputs = encoder(source_seq, en_initial_states)
        en_states = en_outputs[1:]
        de_states = en_states

        de_outputs = decoder(target_seq_in, de_states)
        logits = de_outputs[0]
        loss = loss_func(target_seq_out, logits)

    variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, variables)
    optimizer.apply_gradients(zip(gradients, variables))

    return loss

# %%
def predict(test_source_text=None):
    if test_source_text is None:
        test_source_text = raw_data_en[np.random.choice(len(raw_data_en))]
    print(test_source_text)
    test_source_seq = en_tokenizer.texts_to_sequences([test_source_text])
    print(test_source_seq)

    en_initial_states = encoder.init_states(1)
    en_outputs = encoder(tf.constant(test_source_seq), en_initial_states)

    de_input = tf.constant([[fr_tokenizer.word_index['<start>']]])
    de_state_h, de_state_c = en_outputs[1:]
    out_words = []

    while True:
        de_output, de_state_h, de_state_c = decoder(
            de_input, (de_state_h, de_state_c))
        de_input = tf.argmax(de_output, -1)
        out_words.append(fr_tokenizer.index_word[de_input.numpy()[0][0]])

        if out_words[-1] == '<end>' or len(out_words) >= 20:
            break

    print(' '.join(out_words))

# %%
NUM_EPOCHS = 300
BATCH_SIZE = 5

for e in range(NUM_EPOCHS):
    en_initial_states = encoder.init_states(BATCH_SIZE)

    for batch, (source_seq, target_seq_in, target_seq_out) in enumerate(dataset.take(-1)):
        loss = train_step(source_seq, target_seq_in,
                          target_seq_out, en_initial_states)

    print("######################")
    print('Epoch {} Loss {:.4f}'.format(e + 1, loss.numpy()))
    print("######################")
    
    try:
        predict()
    except Exception:
      continue
# Out:
# ######################
# Epoch 1 Loss 3.2203
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# . <end>
# ######################
# Epoch 2 Loss 3.3504
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# . <end>
# ######################
# Epoch 3 Loss 3.7390
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous . <end>
# ######################
# Epoch 4 Loss 3.2635
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# vous . <end>
# ######################
# Epoch 5 Loss 3.6375
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous <end>
# ######################
# Epoch 6 Loss 3.7904
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# vous <end>
# ######################
# Epoch 7 Loss 2.8103
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous <end>
# ######################
# Epoch 8 Loss 2.8804
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# vous <end>
# ######################
# Epoch 9 Loss 3.0216
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# vous <end>
# ######################
# Epoch 10 Loss 3.1500
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous <end>
# ######################
# Epoch 11 Loss 3.1584
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# vous vous vous vous <end>
# ######################
# Epoch 12 Loss 3.2807
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous vous vous vous <end>
# ######################
# Epoch 13 Loss 3.1220
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous vous vous vous <end>
# ######################
# Epoch 14 Loss 2.5980
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous vous vous <end>
# ######################
# Epoch 15 Loss 2.9972
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# vous vous vous vous vous <end>
# ######################
# Epoch 16 Loss 2.9455
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# vous vous vous vous vous <end>
# ######################
# Epoch 17 Loss 3.3174
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous vous vous vous vous vous <end>
# ######################
# Epoch 18 Loss 2.6106
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous vous vous vous <end>
# ######################
# Epoch 19 Loss 2.7997
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous vous vous vous vous <end>
# ######################
# Epoch 20 Loss 2.9151
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous vous vous vous <end>
# ######################
# Epoch 21 Loss 2.6308
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous vous vous vous <end>
# ######################
# Epoch 22 Loss 2.5743
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# vous vous vous vous <end>
# ######################
# Epoch 23 Loss 2.4682
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous vous vous vous vous vous vous <end>
# ######################
# Epoch 24 Loss 3.3683
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# vous vous vous vous vous vous <end>
# ######################
# Epoch 25 Loss 2.7769
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous vous vous vous vous vous <end>
# ######################
# Epoch 26 Loss 2.8855
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous vous vous vous <end>
# ######################
# Epoch 27 Loss 2.7811
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# vous vous vous <end>
# ######################
# Epoch 28 Loss 2.5151
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous vous vous vous vous vous vous . <end>
# ######################
# Epoch 29 Loss 2.9544
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous vous vous vous . <end>
# ######################
# Epoch 30 Loss 2.8875
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous vous vous <end>
# ######################
# Epoch 31 Loss 2.3613
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# vous vous vous vous <end>
# ######################
# Epoch 32 Loss 2.6688
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# . <end>
# ######################
# Epoch 33 Loss 2.2040
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous vous vous vous <end>
# ######################
# Epoch 34 Loss 2.8934
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous vous vous vous vous vous . <end>
# ######################
# Epoch 35 Loss 2.4804
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous vous vous <end>
# ######################
# Epoch 36 Loss 2.4825
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# vous vous vous vous vous vous vous <end>
# ######################
# Epoch 37 Loss 2.5907
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# vous vous a a vous <end>
# ######################
# Epoch 38 Loss 2.4966
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# vous vous a a vous <end>
# ######################
# Epoch 39 Loss 2.4519
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous vous a a vous <end>
# ######################
# Epoch 40 Loss 2.2029
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous vous a a vous <end>
# ######################
# Epoch 41 Loss 2.6661
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# vous vous vous vous <end>
# ######################
# Epoch 42 Loss 2.1775
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# vous vous a a <end>
# ######################
# Epoch 43 Loss 2.4588
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous vous a a <end>
# ######################
# Epoch 44 Loss 2.0848
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 45 Loss 2.6673
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# vous a a . <end>
# ######################
# Epoch 46 Loss 2.4065
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# vous vous vous a a vous <end>
# ######################
# Epoch 47 Loss 2.2924
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 48 Loss 2.4285
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# vous vous <end>
# ######################
# Epoch 49 Loss 2.3949
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# vous vous <end>
# ######################
# Epoch 50 Loss 2.6236
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# je vous a a . <end>
# ######################
# Epoch 51 Loss 2.3332
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# je vous a a . <end>
# ######################
# Epoch 52 Loss 2.1389
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous vous a a <end>
# ######################
# Epoch 53 Loss 2.3189
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 54 Loss 2.0087
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous vous vous vous a vous les ? <end>
# ######################
# Epoch 55 Loss 2.1319
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# vous vous vous vous a vous les ? <end>
# ######################
# Epoch 56 Loss 2.1394
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# je vous a a . <end>
# ######################
# Epoch 57 Loss 2.3044
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 58 Loss 2.2062
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je vous vous a a a les . <end>
# ######################
# Epoch 59 Loss 2.2797
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous vous a a <end>
# ######################
# Epoch 60 Loss 1.7386
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# je vous a a . <end>
# ######################
# Epoch 61 Loss 1.9549
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 62 Loss 2.0893
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# vous vous a a la <end>
# ######################
# Epoch 63 Loss 2.0478
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 64 Loss 1.8958
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 65 Loss 1.8500
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je vous vous a a la les . <end>
# ######################
# Epoch 66 Loss 2.1409
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous a a . <end>
# ######################
# Epoch 67 Loss 1.6726
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# je vous a a . <end>
# ######################
# Epoch 68 Loss 1.9640
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# vous a a a . <end>
# ######################
# Epoch 69 Loss 1.8135
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# ce a a a . <end>
# ######################
# Epoch 70 Loss 1.5689
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# je vous a a . <end>
# ######################
# Epoch 71 Loss 1.6455
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 72 Loss 1.6780
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept <end>
# ######################
# Epoch 73 Loss 1.4474
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l beaucoup de beaucoup de de de de de de beaucoup de beaucoup de beaucoup beaucoup honnetete honnetete honnetete produit
# ######################
# Epoch 74 Loss 1.6064
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je je avoir minutes vous vous ? <end>
# ######################
# Epoch 75 Loss 1.7082
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# ce a a a . <end>
# ######################
# Epoch 76 Loss 1.6727
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# n est a a . <end>
# ######################
# Epoch 77 Loss 1.4913
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# l beaucoup de beaucoup de de de de de de de beaucoup de beaucoup de beaucoup beaucoup honnetete honnetete honnetete
# ######################
# Epoch 78 Loss 1.5344
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous vous de de m cela cela les les . <end>
# ######################
# Epoch 79 Loss 1.3535
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# je vous a autre . <end>
# ######################
# Epoch 80 Loss 1.7064
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# ce vous a a a . <end>
# ######################
# Epoch 81 Loss 1.4546
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous a a la . <end>
# ######################
# Epoch 82 Loss 1.4644
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# je vous a a la . <end>
# ######################
# Epoch 83 Loss 1.4912
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# vous vous de de cela cela les les . <end>
# ######################
# Epoch 84 Loss 1.6528
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous pas a la longue . <end>
# ######################
# Epoch 85 Loss 1.1685
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# est a a longue . <end>
# ######################
# Epoch 86 Loss 1.2650
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous vous de de cela cela les les . <end>
# ######################
# Epoch 87 Loss 1.3329
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous vous pas a la des . <end>
# ######################
# Epoch 88 Loss 1.1621
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous de a la les les . <end>
# ######################
# Epoch 89 Loss 1.3830
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# l de a a la la longue . <end>
# ######################
# Epoch 90 Loss 1.3688
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# ce est a a la longue . <end>
# ######################
# Epoch 91 Loss 1.4031
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 92 Loss 1.3694
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 93 Loss 1.5008
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez de de cela cela les les . <end>
# ######################
# Epoch 94 Loss 1.1503
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# vous vous de de m cela tous les trois . <end>
# ######################
# Epoch 95 Loss 1.2774
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je avoir quelques minutes vous vous ? <end>
# ######################
# Epoch 96 Loss 1.1153
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je je vous a a la deux . <end>
# ######################
# Epoch 97 Loss 1.1815
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est de de la cela cela les trois . <end>
# ######################
# Epoch 98 Loss 1.0327
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# l de a a la la longue . <end>
# ######################
# Epoch 99 Loss 1.0934
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je avoir quelques minutes vous vous ? <end>
# ######################
# Epoch 100 Loss 1.1800
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# ? <end>
# ######################
# Epoch 101 Loss 1.1913
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous a a la . <end>
# ######################
# Epoch 102 Loss 1.1441
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est de de la cela cela les trois . <end>
# ######################
# Epoch 103 Loss 1.2111
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous vous a a la . <end>
# ######################
# Epoch 104 Loss 0.9070
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# quel ridicule ridicule <end>
# ######################
# Epoch 105 Loss 1.1616
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# concept ! <end>
# ######################
# Epoch 106 Loss 1.0188
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# vous vous avez de cela tous les les . <end>
# ######################
# Epoch 107 Loss 0.7096
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une chance ? <end>
# ######################
# Epoch 108 Loss 0.9224
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# est de a la la longue . <end>
# ######################
# Epoch 109 Loss 0.9925
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est de de la cela cela les trois . <end>
# ######################
# Epoch 110 Loss 0.7338
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# concept ! <end>
# ######################
# Epoch 111 Loss 0.9879
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est de de la cela cela les trois . <end>
# ######################
# Epoch 112 Loss 0.9505
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# concept ! <end>
# ######################
# Epoch 113 Loss 1.0344
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous pas a la longue . <end>
# ######################
# Epoch 114 Loss 1.0132
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# est a la longue . <end>
# ######################
# Epoch 115 Loss 0.8989
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# est de a la la longue . <end>
# ######################
# Epoch 116 Loss 0.9919
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est ce est a a la longue . <end>
# ######################
# Epoch 117 Loss 0.9302
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 118 Loss 0.8590
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous de m excuser ! vous parler ? <end>
# ######################
# Epoch 119 Loss 0.7509
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous de m excuser ! vous parler ? <end>
# ######################
# Epoch 120 Loss 0.8902
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de cela cela les trois . <end>
# ######################
# Epoch 121 Loss 0.6666
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est ce est a a la longue . <end>
# ######################
# Epoch 122 Loss 0.8088
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent que cela cela veut dire . <end>
# ######################
# Epoch 123 Loss 0.9299
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas folle . <end>
# ######################
# Epoch 124 Loss 0.7316
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de cela cela les trois . <end>
# ######################
# Epoch 125 Loss 0.6630
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# vous vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 126 Loss 0.6558
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous vous de m excuser ! savez vous ? <end>
# ######################
# Epoch 127 Loss 0.7754
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire vous abandonniez . <end>
# ######################
# Epoch 128 Loss 0.5904
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas folle . <end>
# ######################
# Epoch 129 Loss 0.7226
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# est a la longue . <end>
# ######################
# Epoch 130 Loss 0.6011
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire vous abandonniez . <end>
# ######################
# Epoch 131 Loss 0.8166
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l paye a la longue . <end>
# ######################
# Epoch 132 Loss 0.6679
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas folle . <end>
# ######################
# Epoch 133 Loss 0.6518
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# concept ! <end>
# ######################
# Epoch 134 Loss 0.4487
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire vous abandonniez . <end>
# ######################
# Epoch 135 Loss 0.5668
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# concept ! <end>
# ######################
# Epoch 136 Loss 0.7108
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 137 Loss 0.7148
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas folle . <end>
# ######################
# Epoch 138 Loss 0.8285
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut dire . <end>
# ######################
# Epoch 139 Loss 0.5579
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# je avoir quelques minutes je vous prie ? <end>
# ######################
# Epoch 140 Loss 0.6308
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# valeur d un homme dans ce qu il est . <end>
# ######################
# Epoch 141 Loss 0.5015
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est ce qu il est est tres mal . <end>
# ######################
# Epoch 142 Loss 0.5417
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est ce qu il est est tres mal . <end>
# ######################
# Epoch 143 Loss 0.5554
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut dire . <end>
# ######################
# Epoch 144 Loss 0.5997
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 145 Loss 0.3774
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# valeur d un homme dans ce qu il est . <end>
# ######################
# Epoch 146 Loss 0.5373
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous vous de m excuser ! savez vous ? <end>
# ######################
# Epoch 147 Loss 0.6976
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut dire . <end>
# ######################
# Epoch 148 Loss 0.5486
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela les trois . <end>
# ######################
# Epoch 149 Loss 0.6359
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une autre ? <end>
# ######################
# Epoch 150 Loss 0.5196
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous prie de m excuser ! savez vous parler anglais ? <end>
# ######################
# Epoch 151 Loss 0.4614
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# concept ! <end>
# ######################
# Epoch 152 Loss 0.5112
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# qu il est l mal . <end>
# ######################
# Epoch 153 Loss 0.3656
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 154 Loss 0.4346
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous prie de m excuser ! savez vous parler anglais ? <end>
# ######################
# Epoch 155 Loss 0.4922
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire vous abandonniez . <end>
# ######################
# Epoch 156 Loss 0.4963
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela les trois . <end>
# ######################
# Epoch 157 Loss 0.4150
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui c est l anniversaire hui ! <end>
# ######################
# Epoch 158 Loss 0.3691
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# qu il est l mal . <end>
# ######################
# Epoch 159 Loss 0.5365
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment vous qu il il s s il agit pas un piege ? <end>
# ######################
# Epoch 160 Loss 0.2958
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une autre ? <end>
# ######################
# Epoch 161 Loss 0.3342
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce vous etudiez a la bibliotheque des fois ? <end>
# ######################
# Epoch 162 Loss 0.3948
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# concept ! <end>
# ######################
# Epoch 163 Loss 0.4086
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas par les apparences . <end>
# ######################
# Epoch 164 Loss 0.2874
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# ######################
# Epoch 165 Loss 0.5052
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 166 Loss 0.3357
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui c est l anniversaire hui ! <end>
# ######################
# Epoch 167 Loss 0.5096
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire vous abandonniez . <end>
# ######################
# Epoch 168 Loss 0.3247
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est ce que il a la tres mal . <end>
# ######################
# Epoch 169 Loss 0.3642
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 170 Loss 0.3646
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# ######################
# Epoch 171 Loss 0.4054
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce vous etudiez a la bibliotheque des fois ? <end>
# ######################
# Epoch 172 Loss 0.3610
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# vous avez plante des citrouilles ? <end>
# ######################
# Epoch 173 Loss 0.4138
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et travaillent tous les deux comme mannequins . <end>
# ######################
# Epoch 174 Loss 0.2805
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui c est l anniversaire hui ! <end>
# ######################
# Epoch 175 Loss 0.3232
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l paye a la longue . <end>
# ######################
# Epoch 176 Loss 0.4944
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes vous prie ? <end>
# ######################
# Epoch 177 Loss 0.3626
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par . <end>
# ######################
# Epoch 178 Loss 0.3284
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes vous prie ? <end>
# ######################
# Epoch 179 Loss 0.2698
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 180 Loss 0.3023
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est ce que il a la tres mal . <end>
# ######################
# Epoch 181 Loss 0.2516
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# ######################
# Epoch 182 Loss 0.2812
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# ######################
# Epoch 183 Loss 0.2454
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une autre chance ? <end>
# ######################
# Epoch 184 Loss 0.3810
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# ######################
# Epoch 185 Loss 0.2923
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 186 Loss 0.3017
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une autre chance ? <end>
# ######################
# Epoch 187 Loss 0.2474
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous avez pas par les apparences . <end>
# ######################
# Epoch 188 Loss 0.2905
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce a a la longue . <end>
# ######################
# Epoch 189 Loss 0.2268
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete a la longue . <end>
# ######################
# Epoch 190 Loss 0.2414
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 191 Loss 0.4085
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# ######################
# Epoch 192 Loss 0.2468
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# ######################
# Epoch 193 Loss 0.1716
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# vous prie de m excuser ! savez vous parler anglais ? <end>
# ######################
# Epoch 194 Loss 0.1939
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ! <end>
# ######################
# Epoch 195 Loss 0.2490
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# ######################
# Epoch 196 Loss 0.2281
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete a la longue . <end>
# ######################
# Epoch 197 Loss 0.2342
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 198 Loss 0.2517
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# ######################
# Epoch 199 Loss 0.2605
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 200 Loss 0.2283
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine qui c est l anniversaire hui ! <end>
# ######################
# Epoch 201 Loss 0.2059
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte il vous plait ? <end>
# ######################
# Epoch 202 Loss 0.3790
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque fois ? <end>
# ######################
# Epoch 203 Loss 0.2241
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# ######################
# Epoch 204 Loss 0.1527
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete a la longue . <end>
# ######################
# Epoch 205 Loss 0.2150
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque fois ? <end>
# ######################
# Epoch 206 Loss 0.1622
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte il vous plait ? <end>
# ######################
# Epoch 207 Loss 0.1931
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes vous prie ? <end>
# ######################
# Epoch 208 Loss 0.2429
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary tous les deux comme mannequins . <end>
# ######################
# Epoch 209 Loss 0.2214
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary tous les deux comme mannequins . <end>
# ######################
# Epoch 210 Loss 0.1602
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# a la <end>
# ######################
# Epoch 211 Loss 0.2209
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une autre chance ? <end>
# ######################
# Epoch 212 Loss 0.1639
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 213 Loss 0.2023
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# ######################
# Epoch 214 Loss 0.2197
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# est ce que il a la tres mal . <end>
# ######################
# Epoch 215 Loss 0.1294
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par les . <end>
# ######################
# Epoch 216 Loss 0.1872
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# ######################
# Epoch 217 Loss 0.1701
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce a a la longue . <end>
# ######################
# Epoch 218 Loss 0.1714
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# ######################
# Epoch 219 Loss 0.1958
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 220 Loss 0.1906
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce a a la longue . <end>
# ######################
# Epoch 221 Loss 0.2180
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 222 Loss 0.1585
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 223 Loss 0.1541
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par les . <end>
# ######################
# Epoch 224 Loss 0.2055
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# ######################
# Epoch 225 Loss 0.1474
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary tous les deux comme mannequins . <end>
# ######################
# Epoch 226 Loss 0.1651
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte il vous plait ? <end>
# ######################
# Epoch 227 Loss 0.0999
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# a la <end>
# ######################
# Epoch 228 Loss 0.1285
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 229 Loss 0.1577
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# ######################
# Epoch 230 Loss 0.2024
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une autre chance ? <end>
# ######################
# Epoch 231 Loss 0.1739
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# idee n est pas completement folle . <end>
# ######################
# Epoch 232 Loss 0.2030
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte il vous plait ? <end>
# ######################
# Epoch 233 Loss 0.1245
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce a a la longue . <end>
# ######################
# Epoch 234 Loss 0.1373
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# a la <end>
# ######################
# Epoch 235 Loss 0.1345
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# ######################
# Epoch 236 Loss 0.1235
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 237 Loss 0.2039
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# ######################
# Epoch 238 Loss 0.1691
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# donnez vous une autre chance ? <end>
# ######################
# Epoch 239 Loss 0.1798
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# ######################
# Epoch 240 Loss 0.1705
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 241 Loss 0.2176
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de c est l anniversaire aujourd hui ! <end>
# ######################
# Epoch 242 Loss 0.1886
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 243 Loss 0.2321
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# ######################
# Epoch 244 Loss 0.1108
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# ######################
# Epoch 245 Loss 0.1147
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 246 Loss 0.1353
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# ######################
# Epoch 247 Loss 0.1579
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous autre chance ? <end>
# ######################
# Epoch 248 Loss 0.1490
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# ######################
# Epoch 249 Loss 0.0918
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 250 Loss 0.1553
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 251 Loss 0.0842
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 252 Loss 0.1192
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# a la <end>
# ######################
# Epoch 253 Loss 0.1015
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# ######################
# Epoch 254 Loss 0.0897
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# ######################
# Epoch 255 Loss 0.1006
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
# ######################
# Epoch 256 Loss 0.0821
# ######################
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# ######################
# Epoch 257 Loss 0.1080
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# ######################
# Epoch 258 Loss 0.1295
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par les . <end>
# ######################
# Epoch 259 Loss 0.1310
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par les . <end>
# ######################
# Epoch 260 Loss 0.1442
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# ######################
# Epoch 261 Loss 0.1204
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# ######################
# Epoch 262 Loss 0.0714
# ######################
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l aujourd hui ! <end>
# ######################
# Epoch 263 Loss 0.1225
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce a fait est tres mal . <end>
# ######################
# Epoch 264 Loss 0.1276
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# ######################
# Epoch 265 Loss 0.1428
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 266 Loss 0.1586
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# ######################
# Epoch 267 Loss 0.1131
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 268 Loss 0.1433
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 269 Loss 0.0700
# ######################
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# ######################
# Epoch 270 Loss 0.1021
# ######################
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l . <end>
# ######################
# Epoch 271 Loss 0.1111
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
# ######################
# Epoch 272 Loss 0.0877
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# ######################
# Epoch 273 Loss 0.1194
# ######################
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte il vous plait ? <end>
# ######################
# Epoch 274 Loss 0.0922
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# ######################
# Epoch 275 Loss 0.0789
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une chance ? <end>
# ######################
# Epoch 276 Loss 0.0727
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par les apparences . <end>
# ######################
# Epoch 277 Loss 0.0881
# ######################
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# ######################
# Epoch 278 Loss 0.0788
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# ######################
# Epoch 279 Loss 0.1087
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# ######################
# Epoch 280 Loss 0.1088
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 281 Loss 0.0694
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 282 Loss 0.1212
# ######################
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# ######################
# Epoch 283 Loss 0.1082
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee est pas completement folle . <end>
# ######################
# Epoch 284 Loss 0.0759
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une chance ? <end>
# ######################
# Epoch 285 Loss 0.0688
# ######################
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# vous laissez pas abuser par les apparences . <end>
# ######################
# Epoch 286 Loss 0.0770
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# ######################
# Epoch 287 Loss 0.0768
# ######################
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
# ######################
# Epoch 288 Loss 0.0925
# ######################
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une chance ? <end>
# ######################
# Epoch 289 Loss 0.1058
# ######################
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce a fait est tres mal . <end>
# ######################
# Epoch 290 Loss 0.1098
# ######################
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# ######################
# Epoch 291 Loss 0.0713
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee est pas completement folle . <end>
# ######################
# Epoch 292 Loss 0.0669
# ######################
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# ######################
# Epoch 293 Loss 0.0736
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# ######################
# Epoch 294 Loss 0.0651
# ######################
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# ######################
# Epoch 295 Loss 0.0789
# ######################
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
# ######################
# Epoch 296 Loss 0.0694
# ######################
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# ######################
# Epoch 297 Loss 0.0673
# ######################
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# ######################
# Epoch 298 Loss 0.0564
# ######################
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# ######################
# Epoch 299 Loss 0.0720
# ######################
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# a la <end>
# ######################
# Epoch 300 Loss 0.0791
# ######################
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee est pas completement folle . <end>

# %%
test_sents = (
    'What a ridiculous concept!',
    'Your idea is not entirely crazy.',
    "A man's worth lies in what he is.",
    'What he did is very wrong.',
    "All three of you need to do that.",
    "Are you giving me another chance?",
    "Both Tom and Mary work as models.",
    "Can I have a few minutes, please?",
    "Could you close the door, please?",
    "Did you plant pumpkins this year?",
    "Do you ever study in the library?",
    "Don't be deceived by appearances.",
    "Excuse me. Can you speak English?",
    "Few people know the true meaning.",
    "Germany produced many scientists.",
    "Guess whose birthday it is today.",
    "He acted like he owned the place.",
    "Honesty will pay in the long run.",
    "How do we know this isn't a trap?",
    "I can't believe you're giving up.",
)

for test_sent in test_sents:
    test_sequence = normalize_string(test_sent)
    predict(test_sequence)
# Out:
# What a ridiculous concept !
# [[8, 5, 21, 22, 23]]
# concept ridicule ! <end>
# Your idea is not entirely crazy .
# [[24, 25, 6, 26, 27, 28, 1]]
# votre idee est pas completement folle . <end>
# A man s worth lies in what he is .
# [[5, 29, 30, 31, 32, 9, 8, 7, 6, 1]]
# la valeur d un homme reside dans ce qu il est . <end>
# What he did is very wrong .
# [[8, 7, 13, 6, 33, 34, 1]]
# ce qu il est tres mal . <end>
# All three of you need to do that .
# [[35, 36, 37, 2, 38, 39, 10, 40, 1]]
# vous avez besoin de faire cela tous les trois . <end>
# Are you giving me another chance ?
# [[41, 2, 14, 15, 42, 43, 3]]
# me donnez vous une chance ? <end>
# Both Tom and Mary work as models .
# [[44, 45, 46, 47, 48, 49, 50, 1]]
# tom et mary travaillent tous les deux comme mannequins . <end>
# Can I have a few minutes please ?
# [[11, 16, 51, 5, 17, 52, 18, 3]]
# puis je avoir quelques minutes je vous prie ? <end>
# Could you close the door please ?
# [[53, 2, 54, 4, 55, 18, 3]]
# vous fermer la porte il vous plait ? <end>
# Did you plant pumpkins this year ?
# [[13, 2, 56, 57, 19, 58, 3]]
# cette avez vous plante des citrouilles ? <end>
# Do you ever study in the library ?
# [[10, 2, 59, 60, 9, 4, 61, 3]]
# est ce que vous etudiez a la bibliotheque des fois ? <end>
# Don t be deceived by appearances .
# [[62, 12, 63, 64, 65, 66, 1]]
# ne vous pas abuser par les apparences . <end>
# Excuse me . Can you speak English ?
# [[67, 15, 1, 11, 2, 68, 69, 3]]
# je vous prie de m excuser ! savez vous parler anglais ? <end>
# Few people know the true meaning .
# [[17, 70, 20, 4, 71, 72, 1]]
# peu de savent ce que cela veut reellement dire . <end>
# Germany produced many scientists .
# [[73, 74, 75, 76, 1]]
# a la <end>
# Guess whose birthday it is today .
# [[77, 78, 79, 80, 6, 81, 1]]
# devine de qui c est l aujourd hui ! <end>
# He acted like he owned the place .
# [[7, 82, 83, 7, 84, 4, 85, 1]]
# il s est comporte comme s il possedait l endroit . <end>
# Honesty will pay in the long run .
# [[86, 87, 88, 9, 4, 89, 90, 1]]
# l honnetete paye a la longue . <end>
# How do we know this isn t a trap ?
# [[91, 10, 92, 20, 19, 93, 12, 5, 94, 3]]
# comment savez vous qu il ne s agit pas d un piege ? <end>
# I can t believe you re giving up .
# [[16, 11, 12, 95, 2, 96, 14, 97, 1]]
# je n arrive pas a croire que vous abandonniez . <end>
